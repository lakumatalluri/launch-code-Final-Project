# %% [markdown]
# # Checkpoint Three: Cleaning Data
#
# Now you are ready to clean your data. Before starting coding, provide the link to your dataset below.
#
# My dataset:
#
# Import the necessary libraries and create your dataframe(s).

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# create a dataframe coviddf (covid-19-country-statistics-dataset.csv)
#to make sure i have original data intact to make any further observations i have created an originaldf
originaldf=pd.read_csv('covid-19-country-statistics-dataset.csv')
coviddf=pd.read_csv('covid-19-country-statistics-dataset.csv')

# %%
# check if the dataframe is loaded correctly
coviddf.head(15)
# Out:
#     Number      Country  Total Cases New Cases Total Deaths  New Deaths  \
# 0        1          USA  106,613,321     1,809    1,159,697        35.0
# 1        2        India   44,924,811       NaN      531,424         NaN
# 2        3       France   39,974,426     6,609      166,425         NaN
# 3        4      Germany   38,400,766       NaN      172,882         NaN
# 4        5       Brazil   37,449,418       NaN      701,494         NaN
# 5        6        Japan   33,689,542    11,764       74,467        24.0
# 6        7     S. Korea   31,129,070    14,284       34,460        11.0
# 7        8        Italy   25,765,219       NaN      189,582         NaN
# 8        9           UK   24,555,629       NaN      221,943         NaN
# 9       10       Russia   22,833,330     6,503      398,208        33.0
# 10      11       Turkey   17,232,066       NaN      102,174         NaN
# 11      12        Spain   13,825,052       NaN      120,715         NaN
# ...

# %%
coviddf=coviddf[coviddf.columns.delete(15)]

# %%
coviddf=coviddf[coviddf.columns.delete(15)]

# %%
coviddf=coviddf[coviddf.columns.delete(15)]

# %%
coviddf=coviddf[coviddf.columns.delete(15)]

# %%
coviddf=coviddf[coviddf.columns.delete(15)]

# %%
coviddf=coviddf[coviddf.columns.delete(15)]

# %%
coviddf.head(10)
# Out:
#    Number   Country  Total Cases New Cases Total Deaths  New Deaths  \
# 0       1       USA  106,613,321     1,809    1,159,697        35.0
# 1       2     India   44,924,811       NaN      531,424         NaN
# 2       3    France   39,974,426     6,609      166,425         NaN
# 3       4   Germany   38,400,766       NaN      172,882         NaN
# 4       5    Brazil   37,449,418       NaN      701,494         NaN
# 5       6     Japan   33,689,542    11,764       74,467        24.0
# 6       7  S. Korea   31,129,070    14,284       34,460        11.0
# 7       8     Italy   25,765,219       NaN      189,582         NaN
# 8       9        UK   24,555,629       NaN      221,943         NaN
# 9      10    Russia   22,833,330     6,503      398,208        33.0
#
#   Total Recovered Active cases Serious_Critical Total Cases Per 1m Pop  \
# 0     104,533,271      920,353            1,392                318,434
# 1      44,335,977       57,410              NaN                 31,938
# ...

# %% [markdown]
# ## Missing Data
#
# Test your dataset for missing data and handle it as needed. Make notes in the form of code comments as to your thought process.

# %%
# finding the percentage of data that is missing in each column
(coviddf.isnull().sum()/coviddf.shape[0])*100
# Out:
# Number                     0.000000
# Country                    0.000000
# Total Cases                0.000000
# New Cases                 84.792627
# Total Deaths               1.382488
# New Deaths                93.087558
# Total Recovered            9.677419
# Active cases               8.755760
# Serious_Critical          42.857143
# Total Cases Per 1m Pop     0.000000
# Deaths Per 1m Pop          1.382488
# Total Tests                5.529954
# Tests Per 1m Pop           5.529954
# Population                 0.000000
# Unnamed: 14                0.000000
# dtype: float64

# %%
# Droping unnecesscary columns and new cases,new deaths,Active case,Serious critical
coviddf=coviddf.drop('New Cases',axis=1)
coviddf.head(10)
# Out:
#    Number   Country  Total Cases Total Deaths  New Deaths Total Recovered  \
# 0       1       USA  106,613,321    1,159,697        35.0     104,533,271
# 1       2     India   44,924,811      531,424         NaN      44,335,977
# 2       3    France   39,974,426      166,425         NaN      39,669,392
# 3       4   Germany   38,400,766      172,882         NaN      38,189,800
# 4       5    Brazil   37,449,418      701,494         NaN      36,249,161
# 5       6     Japan   33,689,542       74,467        24.0      21,725,273
# 6       7  S. Korea   31,129,070       34,460        11.0      30,879,606
# 7       8     Italy   25,765,219      189,582         NaN      25,439,463
# 8       9        UK   24,555,629      221,943         NaN      24,305,452
# 9      10    Russia   22,833,330      398,208        33.0      22,229,208
#
#   Active cases Serious_Critical Total Cases Per 1m Pop Deaths Per 1m Pop  \
# 0      920,353            1,392                318,434             3,464
# ...

# %%
coviddf=coviddf.drop('New Deaths',axis=1)
coviddf.head(10)
# Out:
#    Number   Country  Total Cases Total Deaths Total Recovered Active cases  \
# 0       1       USA  106,613,321    1,159,697     104,533,271      920,353
# 1       2     India   44,924,811      531,424      44,335,977       57,410
# 2       3    France   39,974,426      166,425      39,669,392      138,609
# 3       4   Germany   38,400,766      172,882      38,189,800       38,084
# 4       5    Brazil   37,449,418      701,494      36,249,161      498,763
# 5       6     Japan   33,689,542       74,467      21,725,273   11,889,802
# 6       7  S. Korea   31,129,070       34,460      30,879,606      215,004
# 7       8     Italy   25,765,219      189,582      25,439,463      136,174
# 8       9        UK   24,555,629      221,943      24,305,452       28,234
# 9      10    Russia   22,833,330      398,208      22,229,208      205,914
#
#   Serious_Critical Total Cases Per 1m Pop Deaths Per 1m Pop    Total Tests  \
# ...

# %%
coviddf=coviddf.drop('Active cases',axis=1)
coviddf.head(10)
# Out:
#    Number   Country  Total Cases Total Deaths Total Recovered  \
# 0       1       USA  106,613,321    1,159,697     104,533,271
# 1       2     India   44,924,811      531,424      44,335,977
# 2       3    France   39,974,426      166,425      39,669,392
# 3       4   Germany   38,400,766      172,882      38,189,800
# 4       5    Brazil   37,449,418      701,494      36,249,161
# 5       6     Japan   33,689,542       74,467      21,725,273
# 6       7  S. Korea   31,129,070       34,460      30,879,606
# 7       8     Italy   25,765,219      189,582      25,439,463
# 8       9        UK   24,555,629      221,943      24,305,452
# 9      10    Russia   22,833,330      398,208      22,229,208
#
#   Serious_Critical Total Cases Per 1m Pop Deaths Per 1m Pop    Total Tests  \
# 0            1,392                318,434             3,464  1,176,758,558
# 1              NaN                 31,938               378    925,077,322
# ...

# %%
coviddf=coviddf.drop('Serious_Critical',axis=1)
coviddf.head(10)
# Out:
#    Number   Country  Total Cases Total Deaths Total Recovered  \
# 0       1       USA  106,613,321    1,159,697     104,533,271
# 1       2     India   44,924,811      531,424      44,335,977
# 2       3    France   39,974,426      166,425      39,669,392
# 3       4   Germany   38,400,766      172,882      38,189,800
# 4       5    Brazil   37,449,418      701,494      36,249,161
# 5       6     Japan   33,689,542       74,467      21,725,273
# 6       7  S. Korea   31,129,070       34,460      30,879,606
# 7       8     Italy   25,765,219      189,582      25,439,463
# 8       9        UK   24,555,629      221,943      24,305,452
# 9      10    Russia   22,833,330      398,208      22,229,208
#
#   Total Cases Per 1m Pop Deaths Per 1m Pop    Total Tests Tests Per 1m Pop  \
# 0                318,434             3,464  1,176,758,558        3,514,755
# 1                 31,938               378    925,077,322          657,654
# ...

# %%
coviddf.head(10)
# Out:
#    Number   Country  Total Cases Total Deaths Total Recovered  \
# 0       1       USA  106,613,321    1,159,697     104,533,271
# 1       2     India   44,924,811      531,424      44,335,977
# 2       3    France   39,974,426      166,425      39,669,392
# 3       4   Germany   38,400,766      172,882      38,189,800
# 4       5    Brazil   37,449,418      701,494      36,249,161
# 5       6     Japan   33,689,542       74,467      21,725,273
# 6       7  S. Korea   31,129,070       34,460      30,879,606
# 7       8     Italy   25,765,219      189,582      25,439,463
# 8       9        UK   24,555,629      221,943      24,305,452
# 9      10    Russia   22,833,330      398,208      22,229,208
#
#   Total Cases Per 1m Pop Deaths Per 1m Pop    Total Tests Tests Per 1m Pop  \
# 0                318,434             3,464  1,176,758,558        3,514,755
# 1                 31,938               378    925,077,322          657,654
# ...

# %%
# finding the  of data that is missing in each column
coviddf.isnull().sum()
# coviddf.shape
# Out:
# Number                     0
# Country                    0
# Total Cases                0
# Total Deaths               3
# Total Recovered           21
# Total Cases Per 1m Pop     0
# Deaths Per 1m Pop          3
# Total Tests               12
# Tests Per 1m Pop          12
# Population                 0
# Unnamed: 14                0
# dtype: int64

# %%
# Removing the null values
coviddf.dropna(how='any',subset=['Total Deaths'], inplace=True)
coviddf.isnull().sum()
# Out:
# Number                     0
# Country                    0
# Total Cases                0
# Total Deaths               0
# Total Recovered           19
# Total Cases Per 1m Pop     0
# Deaths Per 1m Pop          0
# Total Tests                9
# Tests Per 1m Pop           9
# Population                 0
# Unnamed: 14                0
# dtype: int64

# %%
coviddf.dropna(how='any',subset=['Total Recovered'], inplace=True)
coviddf.isnull().sum()
# Out:
# Number                    0
# Country                   0
# Total Cases               0
# Total Deaths              0
# Total Recovered           0
# Total Cases Per 1m Pop    0
# Deaths Per 1m Pop         0
# Total Tests               6
# Tests Per 1m Pop          6
# Population                0
# Unnamed: 14               0
# dtype: int64

# %%
coviddf.dropna(how='any',subset=['Total Tests'], inplace=True)
coviddf.isnull().sum()
# Out:
# Number                    0
# Country                   0
# Total Cases               0
# Total Deaths              0
# Total Recovered           0
# Total Cases Per 1m Pop    0
# Deaths Per 1m Pop         0
# Total Tests               0
# Tests Per 1m Pop          0
# Population                0
# Unnamed: 14               0
# dtype: int64

# %%
#finding the shape of rows and columns
coviddf.shape
# Out:
# (189, 11)

# %% [markdown]
# ## Irregular Data
#
# Detect outliers in your dataset and handle them as needed. Use code comments to make notes about your thought process.

# %%
# one column is unnamed:14 changing the column name
coviddf.head(15)
# Out:
#     Number      Country  Total Cases Total Deaths Total Recovered  \
# 0        1          USA  106,613,321    1,159,697     104,533,271
# 1        2        India   44,924,811      531,424      44,335,977
# 2        3       France   39,974,426      166,425      39,669,392
# 3        4      Germany   38,400,766      172,882      38,189,800
# 4        5       Brazil   37,449,418      701,494      36,249,161
# 5        6        Japan   33,689,542       74,467      21,725,273
# 6        7     S. Korea   31,129,070       34,460      30,879,606
# 7        8        Italy   25,765,219      189,582      25,439,463
# 8        9           UK   24,555,629      221,943      24,305,452
# 9       10       Russia   22,833,330      398,208      22,229,208
# 11      12        Spain   13,825,052      120,715      13,665,628
# 12      13      Vietnam   11,554,875       43,188      10,619,813
# 13      14    Australia   11,411,267       20,154      11,342,700
# ...

# %%
coviddf.rename(columns={'Unnamed: 14':'Continent'},inplace=True)
coviddf.head(5)
# Out:
#    Number  Country  Total Cases Total Deaths Total Recovered  \
# 0       1      USA  106,613,321    1,159,697     104,533,271
# 1       2    India   44,924,811      531,424      44,335,977
# 2       3   France   39,974,426      166,425      39,669,392
# 3       4  Germany   38,400,766      172,882      38,189,800
# 4       5   Brazil   37,449,418      701,494      36,249,161
#
#   Total Cases Per 1m Pop Deaths Per 1m Pop    Total Tests Tests Per 1m Pop  \
# 0                318,434             3,464  1,176,758,558        3,514,755
# 1                 31,938               378    925,077,322          657,654
# 2                609,510             2,538    271,490,188        4,139,547
# 3                457,786             2,061    122,332,384        1,458,359
# 4                173,897             3,257     63,776,166          296,146
#
#       Population      Continent
# 0    334,805,269  North America
# 1  1,406,631,776           Asia
# 2     65,584,518         Europe
# ...

# %% [markdown]
# ## Unnecessary Data
#
# Look for the different types of unnecessary data in your dataset and address it as needed. Make sure to use code comments to illustrate your thought process.

# %%
# Droping unnecesscary columns and new cases,new deaths,Active case,Serious critical
#in the missing data.

# %% [markdown]
# ## Inconsistent Data
#
# Check for inconsistent data and address any that arises. As always, use code comments to illustrate your thought process.

# %%
coviddf[['Total Cases']]=coviddf[['Total Cases']].replace(',','' , regex=True).astype(int)
coviddf.head(10)
# Out:
#    Number   Country  Total Cases Total Deaths Total Recovered  \
# 0       1       USA    106613321    1,159,697     104,533,271
# 1       2     India     44924811      531,424      44,335,977
# 2       3    France     39974426      166,425      39,669,392
# 3       4   Germany     38400766      172,882      38,189,800
# 4       5    Brazil     37449418      701,494      36,249,161
# 5       6     Japan     33689542       74,467      21,725,273
# 6       7  S. Korea     31129070       34,460      30,879,606
# 7       8     Italy     25765219      189,582      25,439,463
# 8       9        UK     24555629      221,943      24,305,452
# 9      10    Russia     22833330      398,208      22,229,208
#
#   Total Cases Per 1m Pop Deaths Per 1m Pop    Total Tests Tests Per 1m Pop  \
# 0                318,434             3,464  1,176,758,558        3,514,755
# 1                 31,938               378    925,077,322          657,654
# ...

# %%
coviddf[['Total Deaths','Total Recovered','Total Cases Per 1m Pop','Deaths Per 1m Pop','Total Tests','Tests Per 1m Pop','Population']]=coviddf[['Total Deaths','Total Recovered','Total Cases Per 1m Pop','Deaths Per 1m Pop','Total Tests','Tests Per 1m Pop','Population']].replace(',','' , regex=True).astype(int)
coviddf.head(10)
# Out:
#    Number   Country  Total Cases  Total Deaths  Total Recovered  \
# 0       1       USA    106613321       1159697        104533271
# 1       2     India     44924811        531424         44335977
# 2       3    France     39974426        166425         39669392
# 3       4   Germany     38400766        172882         38189800
# 4       5    Brazil     37449418        701494         36249161
# 5       6     Japan     33689542         74467         21725273
# 6       7  S. Korea     31129070         34460         30879606
# 7       8     Italy     25765219        189582         25439463
# 8       9        UK     24555629        221943         24305452
# 9      10    Russia     22833330        398208         22229208
#
#    Total Cases Per 1m Pop  Deaths Per 1m Pop  Total Tests  Tests Per 1m Pop  \
# 0                  318434               3464   1176758558           3514755
# 1                   31938                378    925077322            657654
# ...

# %% [markdown]
# ## Summarize Your Results
#
# Make note of your answers to the following questions.
#
# 1. Did you find all four types of dirty data in your dataset?
# Yes, I found missing data, inaccurate data, inconsistent data and unnecessary data
# 2. Did the process of cleaning your data give you new insights into your dataset?
# Yes, It helped me unnderstand my data better also ideas on how to interpret it to answer my business questions.
# 3. Is there anything you would like to make note of when it comes to manipulating the data and making visualizations?
# I changed the data type of certain columns to integer to help me with visualizations and manipulation in the next step.

# %%
coviddf.to_csv("covid_dataset.csv",sep=',')

# %%
newcoviddf=pd.read_csv("covid_dataset.csv")
newcoviddf.head(10)
# Out:
#    Unnamed: 0  Number   Country  Total Cases  Total Deaths  Total Recovered  \
# 0           0       1       USA    106613321       1159697        104533271
# 1           1       2     India     44924811        531424         44335977
# 2           2       3    France     39974426        166425         39669392
# 3           3       4   Germany     38400766        172882         38189800
# 4           4       5    Brazil     37449418        701494         36249161
# 5           5       6     Japan     33689542         74467         21725273
# 6           6       7  S. Korea     31129070         34460         30879606
# 7           7       8     Italy     25765219        189582         25439463
# 8           8       9        UK     24555629        221943         24305452
# 9           9      10    Russia     22833330        398208         22229208
#
#    Total Cases Per 1m Pop  Deaths Per 1m Pop  Total Tests  Tests Per 1m Pop  \
# ...
